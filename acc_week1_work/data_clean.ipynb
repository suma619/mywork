# %%
import pandas as pd
file="Presidents2.csv"
df = pd.read_csv(file)
#print(df['National total votes'])
df.isnull()
# Out:
#      President  Years in office  Year first inaugurated  Age at inauguration  \
# 0        False            False                   False                False
# 1        False            False                   False                False
# 2        False            False                   False                False
# 3        False            False                   False                False
# 4        False            False                   False                False
# 5        False            False                   False                False
# 6        False            False                   False                False
# 7        False            False                   False                False
# 8        False            False                   False                False
# 9        False            False                   False                False
# 10       False            False                   False                False
# ...

# %%
df
# Out:
#                   President Years in office Year first inaugurated  \
# 0         George Washington               8                   1789
# 1                John Adams               4                   1797
# 2          Thomas Jefferson               8                   1801
# 3             James Madison               8                   1809
# 4              James Monroe               8                   1817
# 5         John Quincy Adams               4                   1825
# 6            Andrew Jackson               8                   1829
# 7         Martin Van Buren                4                   1837
# 8    William Henry Harrison             0.8                   1841
# 9             James K. Polk               4                   1845
# 10           Zachary Taylor               1                   1849
# 11          Franklin Pierce               4                   1853
# 12           James Buchanan               4                   1857
# ...

# %%
df['# of electoral votes'].fillna(0, inplace=True)

# %%
df['Years in office'].fillna(0, inplace=True)

# %%
df
# Out:
#                   President Years in office Year first inaugurated  \
# 0         George Washington               8                   1789
# 1                John Adams               4                   1797
# 2          Thomas Jefferson               8                   1801
# 3             James Madison               8                   1809
# 4              James Monroe               8                   1817
# 5         John Quincy Adams               4                   1825
# 6            Andrew Jackson               8                   1829
# 7         Martin Van Buren                4                   1837
# 8    William Henry Harrison             0.8                   1841
# 9             James K. Polk               4                   1845
# 10           Zachary Taylor               1                   1849
# 11          Franklin Pierce               4                   1853
# 12           James Buchanan               4                   1857
# ...

# %%
df.loc[df['President']=='President']
# Out:
#     President  Years in office  Year first inaugurated  Age at inauguration  \
# 35  President  Years in office  Year first inaugurated  Age at inauguration
# 65  President  Years in office  Year first inaugurated  Age at inauguration
#
#     State elected from  # of electoral votes    # of popular votes   \
# 35  State elected from  # of electoral votes  Total electoral votes
# 65  State elected from  # of electoral votes    # of popular votes
#
#      National total votes    Total electoral votes  Rating points  \
# 35     # of popular votes    National total votes   Rating points
# 65   National total votes    Total electoral votes  Rating points
#
#     Political Party  Occupation  College  % electoral  % popular
# 35  Political Party  Occupation  College  % electoral  % popular
# 65  Political Party  Occupation  College  % electoral  % popular

# %%
df.drop(df['President']=='President', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-56-43f7825d36f2> in <module>()
# ----> 1 df.drop(df['President']=='President', inplace=True)
#
# c:\users\suma\appdata\local\programs\python\python35\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# c:\users\suma\appdata\local\programs\python\python35\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-aeff71ac89b6> in <module>()
# ----> 1 df.drop('President',axis=0)
#
# c:\users\suma\appdata\local\programs\python\python35\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# c:\users\suma\appdata\local\programs\python\python35\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
#    3110             if labels is not None:
# ...
