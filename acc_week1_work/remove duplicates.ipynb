# %%
import pandas
df = pandas.read_csv('logs1.csv', header = 0)
df['count'] = df.groupby(['file'])['failure'].transform('sum')
df=df.drop_duplicates()
df
# Out:
#                                                    file  success  failure  \
# 0                         "GET / HTTP/1.1" 403 4890 "-"      0.0      1.0
# 1                                                   NaN      NaN      NaN
# 2     "GET /icons/apache_pb2.gif HTTP/1.1" 200 4234 ...      1.0      0.0
# 4     "GET /icons/poweredby.png HTTP/1.1" 200 3412 "...      1.0      0.0
# 6               "GET /favicon.ico HTTP/1.1" 404 209 "-"      0.0      1.0
# 10                 "GET /info.php HTTP/1.1" 404 206 "-"      0.0      1.0
# 12            "GET /phpinfo.php HTTP/1.1" 200 83856 "-"      1.0      0.0
# 14               "GET /phpMyAdmin HTTP/1.1" 301 240 "-"      0.0      1.0
# 16             "GET /phpMyAdmin/ HTTP/1.1" 200 3446 "-"      1.0      0.0
# 18    "GET /phpMyAdmin/themes/pmahomme/jquery/jquery...      1.0      0.0
# 20    "GET /phpMyAdmin/js/vendor/codemirror/lib/code...      1.0      0.0
# 22    "GET /phpMyAdmin/js/vendor/codemirror/addon/hi...      1.0      0.0
# ...

# %%
df.to_csv (r'logs/logs2.csv', index = None, header=True)

# %%
import numpy as np

# %%
df
# Out:
#                                                    file  success  failure  \
# 0                         "GET / HTTP/1.1" 403 4890 "-"      0.0      1.0
# 1                                                   NaN      NaN      NaN
# 2     "GET /icons/apache_pb2.gif HTTP/1.1" 200 4234 ...      1.0      0.0
# 4     "GET /icons/poweredby.png HTTP/1.1" 200 3412 "...      1.0      0.0
# 6               "GET /favicon.ico HTTP/1.1" 404 209 "-"      0.0      1.0
# 10                 "GET /info.php HTTP/1.1" 404 206 "-"      0.0      1.0
# 12            "GET /phpinfo.php HTTP/1.1" 200 83856 "-"      1.0      0.0
# 14               "GET /phpMyAdmin HTTP/1.1" 301 240 "-"      0.0      1.0
# 16             "GET /phpMyAdmin/ HTTP/1.1" 200 3446 "-"      1.0      0.0
# 18    "GET /phpMyAdmin/themes/pmahomme/jquery/jquery...      1.0      0.0
# 20    "GET /phpMyAdmin/js/vendor/codemirror/lib/code...      1.0      0.0
# 22    "GET /phpMyAdmin/js/vendor/codemirror/addon/hi...      1.0      0.0
# ...

# %%
df.loc[df['count'] == 0, ['count']] =1

# %%
df.to_csv (r'logs/logs4.csv', index = None, header=True)
