# %%
import pandas as pd
file_name="sep 8.xlsx"
dfs = pd.read_excel(file_name, sheet_name="Sheet")
#dfs2=pd.read_excel(file_name, sheet_name="Sheet1")

# %%
new_header = dfs.iloc[2] #grab the first row for the header
dfs = dfs[3:] #take the data less the header row
dfs.columns = new_header #set the header row as the df header

# %%
dfs
# Out:
# 2                                                   Sno  \
# 3                                                     1
# 4                                                     2
# 5                                                     3
# 6                                                     4
# 7                                                     5
# 8                                                     6
# 9                                                     7
# 10                                                    8
# 11                                                    9
# 12                                                   10
# 13                                                   11
# 14                                                   12
# 15                                                   13
# 16                                                   14
# 17                                                   15
# 18                                                   16
# ...

# %%
dfs.to_excel("output.xlsx")
